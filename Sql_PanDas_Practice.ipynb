# %%
import pandas as pandas
import numpy as numpy
import sqlite3

print("SQL Version is : - ", sqlite3.version)

connection = sqlite3.connect("company.db")

cursor = connection.cursor()

cursor.execute("""
CREATE TABLE employees (
    id INTEGER PRIMARY KEY,
    name TEXT,
    department TEXT,
    salary INTEGER
)
""")

connection.commit()
# Out:
# SQL Version is : -  2.6.0
# /tmp/ipython-input-1541/327510098.py:5: DeprecationWarning: version is deprecated and will be removed in Python 3.14
#   print("SQL Version is : - ", sqlite3.version)
